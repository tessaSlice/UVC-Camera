# %%
import cv2
from matplotlib import pyplot as plt

# %% [markdown]
# # Connecting to the webcam

# %%
cap = cv2.VideoCapture(0) # basically guessing it

#get a frame from the capture device
ret, frame = cap.read()

ret #MUST be true to continue on
# Out:
# True

# %%
plt.imshow(frame)

# %%
cap.release() # good for releasing the capture

# %% [markdown]
# # Making it a live video feed

# %%
# connect to webcam
cap = cv2.VideoCapture(0)
# loop through every frame until webcam is closed
while cap.isOpened():
    ret, frame = cap.read()

    # show image
    cv2.imshow('Webcam', frame)

    # checks whether q has been hit and stops the loop
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
# closes the frame
cv2.destroyAllWindows()

# %% [markdown]
# # Source for all of the code blocks above is through this video: https://youtu.be/FygLqV15TxQ

# %% [markdown]
# # Next goal - grab live feed & stream it onto a website
